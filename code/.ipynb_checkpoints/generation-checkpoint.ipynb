# %%
import torch
import torchvision
from torchvision import transforms, datasets
import numpy as np
import matplotlib.pyplot as plt
import time
import os
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import scipy.misc

# %%
data_transform = transforms.Compose([
        transforms.Resize((300,300)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])

train_dataset = datasets.ImageFolder(root='../novel-data/train',
                                           transform=data_transform)
train_dataset_loader = torch.utils.data.DataLoader(train_dataset,
                                             batch_size=10, shuffle=True,
                                             num_workers=4)
test_dataset = datasets.ImageFolder(root='../novel-data/test',
                                           transform=data_transform)
test_dataset_loader = torch.utils.data.DataLoader(test_dataset,
                                             batch_size=140, shuffle=True,
                                             num_workers=4)
test_x, test_y = next(iter(test_dataset_loader))
test_x, test_y = Variable(test_x), Variable(test_y)

# %% [markdown]
# ### Jittering

# %%
def augment_brightness_camera_images(image):
    image1 = cv2.cvtColor(image,cv2.COLOR_RGB2HSV)
    random_bright = .25+np.random.uniform()
    #print(random_bright)
    image1[:,:,2] = image1[:,:,2]*random_bright
    image1 = cv2.cvtColor(image1,cv2.COLOR_HSV2RGB)
    return image1

def transform_image(img, ang_range, shear_range, trans_range, brightness=0):
    '''
    This function transforms images to generate new images.
    The function takes in following arguments,
    1- Image
    2- ang_range: Range of angles for rotation
    3- shear_range: Range of values to apply affine transform to
    4- trans_range: Range of values to apply translations over.

    A Random uniform distribution is used to generate different parameters for transformation

    '''
    # Rotation

    ang_rot = np.random.uniform(ang_range)-ang_range/2
    rows,cols,ch = img.shape    
    Rot_M = cv2.getRotationMatrix2D((cols/2,rows/2),ang_rot,1)

    # Translation
    tr_x = trans_range*np.random.uniform()-trans_range/2
    tr_y = trans_range*np.random.uniform()-trans_range/2
    Trans_M = np.float32([[1,0,tr_x],[0,1,tr_y]])

    # Shear
    pts1 = np.float32([[5,5],[20,5],[5,20]])

    pt1 = 5+shear_range*np.random.uniform()-shear_range/2
    pt2 = 20+shear_range*np.random.uniform()-shear_range/2

    # Brightness


    pts2 = np.float32([[pt1,5],[pt2,pt1],[5,pt2]])

    shear_M = cv2.getAffineTransform(pts1,pts2)

    img = cv2.warpAffine(img,Rot_M,(cols,rows))
    img = cv2.warpAffine(img,Trans_M,(cols,rows))
    img = cv2.warpAffine(img,shear_M,(cols,rows))

    #if brightness == 1:
    #  img = augment_brightness_camera_images(img)

    return img

# %%
pic = mpimg.imread('../novel-data/train/' + 'person13' + '/face-' + str(1) + '.png')
scipy.misc.imsave('../novel-data/train/' + 'person13/face-6.png', pic)
#cv2.imwrite('../novel-data/train/' + 'person13/face-6.png', pic)
# Out:
# C:\Users\Ananya\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.

# %%
for f in range(10,15):
    folder = 'person' + str(f)
    for k in range(1,6):
        try:
            pic = mpimg.imread('../novel-data/train/' + folder + '/face-' + str(k) + '.png')
        except:
            pic = mpimg.imread('../novel-data/train/' + folder + '/face-' + str(k) + '.jpg')
        gs1 = gridspec.GridSpec(10, 10)
        gs1.update(wspace=0.01, hspace=0.02) # set the spacing between axes.
        plt.figure(figsize=(12,12))
        for i in range(9):
            ax1 = plt.subplot(gs1[i])
            ax1.set_xticklabels([])
            ax1.set_yticklabels([])
            ax1.set_aspect('equal')
            img = transform_image(pic,20,5,5,brightness=1)
            print(k + k*5 + i)
            #scipy.misc.imsave('../novel-data/train/' + folder + '/face-' + str(k+5+i), pic)
            plt.subplot(10,10,i+1)
            plt.imshow(img)
            plt.axis('off')

        plt.show()
# Out:
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 20
# 18
# 19
# 20
# 21
# 22
# 23
# 24
# 25
# 26
# 24
# 25
# 26
# 27
# 28
# 29
# 30
# 31
# 32
# 30
# 31
# 32
# 33
# 34
# 35
# 36
# 37
# 38
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 20
# 18
# 19
# 20
# 21
# 22
# 23
# 24
# 25
# 26
# 24
# 25
# 26
# 27
# 28
# 29
# 30
# 31
# 32
# 30
# 31
# 32
# 33
# 34
# 35
# 36
# 37
# 38
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 20
# 18
# 19
# 20
# 21
# 22
# 23
# 24
# 25
# 26
# 24
# 25
# 26
# 27
# 28
# 29
# 30
# 31
# 32
# 30
# 31
# 32
# 33
# 34
# 35
# 36
# 37
# 38
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 20
# 18
# 19
# 20
# 21
# 22
# 23
# 24
# 25
# 26
# 24
# 25
# 26
# 27
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-e5515760f2e5> in <module>()
#      10         plt.figure(figsize=(12,12))
#      11         for i in range(9):
# ---> 12             ax1 = plt.subplot(gs1[i])
#      13             ax1.set_xticklabels([])
#      14             ax1.set_yticklabels([])
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1048
#    1049     fig = gcf()
# -> 1050     a = fig.add_subplot(*args, **kwargs)
#    1051     bbox = a.bbox
#    1052     byebye = []
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1072                     self._axstack.remove(ax)
#    1073
# -> 1074             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1075
#    1076         self._axstack.add(key, a)
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, axisbg, **kwargs)
#     539
#     540         self._connected = {}  # a dict from events to (id, func)
# --> 541         self.cla()
#     542         # funcs used to format x and y - fall back on major formatters
#     543         self.fmt_xdata = None
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#     980         self.yaxis.cla()
#     981         for name, spine in six.iteritems(self.spines):
# --> 982             spine.cla()
#     983
#     984         self.ignore_existing_data_limits = True
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\spines.py in cla(self)
#     181         self._position = None  # clear position
#     182         if self.axis is not None:
# --> 183             self.axis.cla()
#     184
#     185     def is_frame_like(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\axis.py in cla(self)
#     771         self._set_artist_props(self.label)
#     772
# --> 773         self.reset_ticks()
#     774
#     775         self.converter = None
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\axis.py in reset_ticks(self)
#     785         del self.minorTicks[:]
#     786
# --> 787         self.majorTicks.extend([self._get_tick(major=True)])
#     788         self.minorTicks.extend([self._get_tick(major=False)])
#     789         self._lastNumMajorTicks = 1
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2095         else:
#    2096             tick_kw = self._minor_tick_kw
# -> 2097         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2098
#    2099     def _get_label(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation)
#     152         self.apply_tickdir(tickdir)
#     153
# --> 154         self.tick1line = self._get_tick1line()
#     155         self.tick2line = self._get_tick2line()
#     156         self.gridline = self._get_gridline()
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\axis.py in _get_tick1line(self)
#     567                           markeredgewidth=self._width,
#     568                           zorder=self._zorder)
# --> 569         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#     570         self._set_artist_props(l)
#     571         return l
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\axes\_base.py in get_yaxis_transform(self, which)
#     777         elif which == 'tick1':
#     778             # for cartesian projection, this is bottom spine
# --> 779             return self.spines['left'].get_spine_transform()
#     780         elif which == 'tick2':
#     781             # for cartesian projection, this is top spine
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\spines.py in get_spine_transform(self)
#     440     def get_spine_transform(self):
#     441         """get the spine transform"""
# --> 442         self._ensure_position_is_set()
#     443         what, how = self._spine_transform
#     444
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\spines.py in _ensure_position_is_set(self)
#     163             # default position
#     164             self._position = ('outward', 0.0)  # in points
# --> 165             self.set_position(self._position)
#     166
#     167     def register_axis(self, axis):
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\spines.py in set_position(self, position)
#     430
#     431         if self.axis is not None:
# --> 432             self.axis.reset_ticks()
#     433         self.stale = True
#     434
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\axis.py in reset_ticks(self)
#     785         del self.minorTicks[:]
#     786
# --> 787         self.majorTicks.extend([self._get_tick(major=True)])
#     788         self.minorTicks.extend([self._get_tick(major=False)])
#     789         self._lastNumMajorTicks = 1
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2095         else:
#    2096             tick_kw = self._minor_tick_kw
# -> 2097         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2098
#    2099     def _get_label(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation)
#     152         self.apply_tickdir(tickdir)
#     153
# --> 154         self.tick1line = self._get_tick1line()
#     155         self.tick2line = self._get_tick2line()
#     156         self.gridline = self._get_gridline()
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\axis.py in _get_tick1line(self)
#     566                           markersize=self._size,
#     567                           markeredgewidth=self._width,
# --> 568                           zorder=self._zorder)
#     569         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#     570         self._set_artist_props(l)
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     400         self._color = None
#     401         self.set_color(color)
# --> 402         self._marker = MarkerStyle(marker, fillstyle)
#     403
#     404         self._markevery = None
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     187         self._marker_function = None
#     188         self.set_fillstyle(fillstyle)
# --> 189         self.set_marker(marker)
#     190
#     191     def __getstate__(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     273
#     274         self._marker = marker
# --> 275         self._recache()
#     276
#     277     def get_path(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\markers.py in _recache(self)
#     209         self._capstyle = 'butt'
#     210         self._filled = True
# --> 211         self._marker_function()
#     212
#     213     if six.PY3:
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\markers.py in _set_tickleft(self)
#     701
#     702     def _set_tickleft(self):
# --> 703         self._transform = Affine2D().scale(-1.0, 1.0)
#     704         self._snap_threshold = 1.0
#     705         self._filled = False
#
# ~\AppData\Local\Continuum\anaconda3\envs\test\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    2071         scale_mtx = np.array(
#    2072             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
# -> 2073         self._mtx = np.dot(scale_mtx, self._mtx)
#    2074         self.invalidate()
#    2075         return self
#
# KeyboardInterrupt:
